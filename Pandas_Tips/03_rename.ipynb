# %% [markdown]
# # Pandas Tips: `rename()`

# %%
import pandas as pd

# %% [markdown]
# Check your pandas version to ensure similar behavior.
#
# _Version 2.1.1 was released September 2023._

# %%
pd.__version__
# Out:
# '2.1.1'

# %% [markdown]
# ### Load data
#
# Load data from GitHub
#
# _Check out my [read_csv video](https://www.youtube.com/watch?v=sTXr73fqybc) to learn more about this step._

# %%
df = pd.read_csv(
    'https://raw.githubusercontent.com/kimfetti/Videos/master/Pandas_Tips/data/customers.csv',
    index_col='ID'
)

# %%
df.head()
# Out:
#      First Name Last Name         Phone          LTV
# ID
# 4576     Sophia    Walker  602-310-9331     $496.87
# 9488     Evelyn    Harris  171-363-6978  $38,424.41
# 7265      Lucas    Foster  139-658-8905  $14,413.64
# 8555     Elijah     Jones  538-241-9868  $13,440.49
# 7023      Mason    Taylor  937-595-5837   $1,777.37

# %% [markdown]
# ## Basics
#
# `.rename()` works by using a **mapper** dictionary with the format:
# <br><br>
#
# <center>{old_name : new_name}</center>

# %% [markdown]
# ### Renaming a column

# %%
df.rename({'First Name': 'first_name'})
# Out:
#      First Name Last Name         Phone          LTV
# ID
# 4576     Sophia    Walker  602-310-9331     $496.87
# 9488     Evelyn    Harris  171-363-6978  $38,424.41
# 7265      Lucas    Foster  139-658-8905  $14,413.64
# 8555     Elijah     Jones  538-241-9868  $13,440.49
# 7023      Mason    Taylor  937-595-5837   $1,777.37
# ...         ...       ...           ...          ...
# 7099      David    Harris  809-428-6034  $12,799.04
# 6743      Henry     Reyes  999-363-7716  $11,043.94
# 3513     Olivia   Sanders             ?  $10,206.00
# 4307       Emma       Cox  748-415-4613   $9,839.57
# 9062      Henry     Brown  412-368-2550  $14,686.60
#
# [1000 rows x 4 columns]

# %%
df.rename(columns={'First Name': 'first_name'})
# Out:
#      first_name Last Name         Phone          LTV
# ID
# 4576     Sophia    Walker  602-310-9331     $496.87
# 9488     Evelyn    Harris  171-363-6978  $38,424.41
# 7265      Lucas    Foster  139-658-8905  $14,413.64
# 8555     Elijah     Jones  538-241-9868  $13,440.49
# 7023      Mason    Taylor  937-595-5837   $1,777.37
# ...         ...       ...           ...          ...
# 7099      David    Harris  809-428-6034  $12,799.04
# 6743      Henry     Reyes  999-363-7716  $11,043.94
# 3513     Olivia   Sanders             ?  $10,206.00
# 4307       Emma       Cox  748-415-4613   $9,839.57
# 9062      Henry     Brown  412-368-2550  $14,686.60
#
# [1000 rows x 4 columns]

# %%
df.rename({'First Name': 'first_name'}, axis=1)
# Out:
#      first_name Last Name         Phone          LTV
# ID
# 4576     Sophia    Walker  602-310-9331     $496.87
# 9488     Evelyn    Harris  171-363-6978  $38,424.41
# 7265      Lucas    Foster  139-658-8905  $14,413.64
# 8555     Elijah     Jones  538-241-9868  $13,440.49
# 7023      Mason    Taylor  937-595-5837   $1,777.37
# ...         ...       ...           ...          ...
# 7099      David    Harris  809-428-6034  $12,799.04
# 6743      Henry     Reyes  999-363-7716  $11,043.94
# 3513     Olivia   Sanders             ?  $10,206.00
# 4307       Emma       Cox  748-415-4613   $9,839.57
# 9062      Henry     Brown  412-368-2550  $14,686.60
#
# [1000 rows x 4 columns]

# %% [markdown]
# It's common for nothing to happen or to receive an error when renaming columns.
#
# Be sure to either:
# - Use the `columns` argument
# - Or set `axis=1`

# %% [markdown]
# ### Renaming a row

# %%
df.head()
# Out:
#      First Name Last Name         Phone          LTV
# ID
# 4576     Sophia    Walker  602-310-9331     $496.87
# 9488     Evelyn    Harris  171-363-6978  $38,424.41
# 7265      Lucas    Foster  139-658-8905  $14,413.64
# 8555     Elijah     Jones  538-241-9868  $13,440.49
# 7023      Mason    Taylor  937-595-5837   $1,777.37

# %%
df.rename({4576: '4576_Sophia'})
# Out:
#             First Name Last Name         Phone          LTV
# ID
# 4576_Sophia     Sophia    Walker  602-310-9331     $496.87
# 9488            Evelyn    Harris  171-363-6978  $38,424.41
# 7265             Lucas    Foster  139-658-8905  $14,413.64
# 8555            Elijah     Jones  538-241-9868  $13,440.49
# 7023             Mason    Taylor  937-595-5837   $1,777.37
# ...                ...       ...           ...          ...
# 7099             David    Harris  809-428-6034  $12,799.04
# 6743             Henry     Reyes  999-363-7716  $11,043.94
# 3513            Olivia   Sanders             ?  $10,206.00
# 4307              Emma       Cox  748-415-4613   $9,839.57
# 9062             Henry     Brown  412-368-2550  $14,686.60
#
# [1000 rows x 4 columns]

# %%
df.rename(index={4576: '4576_Sophia'})
# Out:
#             First Name Last Name         Phone          LTV
# ID
# 4576_Sophia     Sophia    Walker  602-310-9331     $496.87
# 9488            Evelyn    Harris  171-363-6978  $38,424.41
# 7265             Lucas    Foster  139-658-8905  $14,413.64
# 8555            Elijah     Jones  538-241-9868  $13,440.49
# 7023             Mason    Taylor  937-595-5837   $1,777.37
# ...                ...       ...           ...          ...
# 7099             David    Harris  809-428-6034  $12,799.04
# 6743             Henry     Reyes  999-363-7716  $11,043.94
# 3513            Olivia   Sanders             ?  $10,206.00
# 4307              Emma       Cox  748-415-4613   $9,839.57
# 9062             Henry     Brown  412-368-2550  $14,686.60
#
# [1000 rows x 4 columns]

# %% [markdown]
# When renaming a row,
# - Explicitly use the `index` argument
# - Or `axis=0` by default if you don't also need to rename columns

# %% [markdown]
# ## $\star$ Level Up $\star$

# %% [markdown]
# ### Making permanent changes: `inplace`

# %%
df.head()
# Out:
#      First Name Last Name         Phone          LTV
# ID
# 4576     Sophia    Walker  602-310-9331     $496.87
# 9488     Evelyn    Harris  171-363-6978  $38,424.41
# 7265      Lucas    Foster  139-658-8905  $14,413.64
# 8555     Elijah     Jones  538-241-9868  $13,440.49
# 7023      Mason    Taylor  937-595-5837   $1,777.37

# %%
df = df.rename(columns={'First Name': 'first_name'})

# %%
df.head()
# Out:
#      first_name Last Name         Phone          LTV
# ID
# 4576     Sophia    Walker  602-310-9331     $496.87
# 9488     Evelyn    Harris  171-363-6978  $38,424.41
# 7265      Lucas    Foster  139-658-8905  $14,413.64
# 8555     Elijah     Jones  538-241-9868  $13,440.49
# 7023      Mason    Taylor  937-595-5837   $1,777.37

# %%
df.rename(columns={'Last Name': 'last_name'}, inplace=True)

# %%
df.head()
# Out:
#      first_name last_name         Phone          LTV
# ID
# 4576     Sophia    Walker  602-310-9331     $496.87
# 9488     Evelyn    Harris  171-363-6978  $38,424.41
# 7265      Lucas    Foster  139-658-8905  $14,413.64
# 8555     Elijah     Jones  538-241-9868  $13,440.49
# 7023      Mason    Taylor  937-595-5837   $1,777.37

# %% [markdown]
# The `inplace` option allows you to change your underlying data.

# %% [markdown]
# ### Renaming multiple items at once

# %%
df.head()
# Out:
#      first_name last_name         Phone          LTV
# ID
# 4576     Sophia    Walker  602-310-9331     $496.87
# 9488     Evelyn    Harris  171-363-6978  $38,424.41
# 7265      Lucas    Foster  139-658-8905  $14,413.64
# 8555     Elijah     Jones  538-241-9868  $13,440.49
# 7023      Mason    Taylor  937-595-5837   $1,777.37

# %%
df.rename(
    index={
        4576: '4576_Sophia',
        9488: '9488_Evelyn'
    },
    columns={
        'LTV': 'lifetime_value'
    },
    inplace=True
)

# %%
df.head()
# Out:
#             first_name last_name         Phone lifetime_value
# ID
# 4576_Sophia     Sophia    Walker  602-310-9331       $496.87
# 9488_Evelyn     Evelyn    Harris  171-363-6978    $38,424.41
# 7265             Lucas    Foster  139-658-8905    $14,413.64
# 8555            Elijah     Jones  538-241-9868    $13,440.49
# 7023             Mason    Taylor  937-595-5837     $1,777.37

# %% [markdown]
# ### Catching missing column names: `errors`

# %%
df.head()
# Out:
#             first_name last_name         Phone lifetime_value
# ID
# 4576_Sophia     Sophia    Walker  602-310-9331       $496.87
# 9488_Evelyn     Evelyn    Harris  171-363-6978    $38,424.41
# 7265             Lucas    Foster  139-658-8905    $14,413.64
# 8555            Elijah     Jones  538-241-9868    $13,440.49
# 7023             Mason    Taylor  937-595-5837     $1,777.37

# %%
df.rename(
    columns = {
        'Phone': 'phone_number',
        'Address': 'home_address'
    }
)
# Out:
#             first_name last_name  phone_number lifetime_value
# ID
# 4576_Sophia     Sophia    Walker  602-310-9331       $496.87
# 9488_Evelyn     Evelyn    Harris  171-363-6978    $38,424.41
# 7265             Lucas    Foster  139-658-8905    $14,413.64
# 8555            Elijah     Jones  538-241-9868    $13,440.49
# 7023             Mason    Taylor  937-595-5837     $1,777.37
# ...                ...       ...           ...            ...
# 7099             David    Harris  809-428-6034    $12,799.04
# 6743             Henry     Reyes  999-363-7716    $11,043.94
# 3513            Olivia   Sanders             ?    $10,206.00
# 4307              Emma       Cox  748-415-4613     $9,839.57
# 9062             Henry     Brown  412-368-2550    $14,686.60
#
# [1000 rows x 4 columns]

# %%
# produces intentional error
df.rename(
    columns = {
        'Phone': 'phone_number',
        'Address': 'home_address'
    },
    errors='raise'
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 2
#       1 # produces intentional error
# ----> 2 df.rename(
#       3     columns = {
#       4         'Phone': 'phone_number',
#       5         'Address': 'home_address'
#       6     },
#       7     errors='raise'
#       8 )
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:5521, in DataFrame.rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5402 def rename(
#    5403     self,
#    5404     mapper: Renamer | None = None,
#    (...)
#    5412     errors: IgnoreRaise = "ignore",
#    5413 ) -> DataFrame | None:
#    5414     """
#    5415     Rename columns or index labels.
#    5416
#    (...)
#    5519     4  3  6
#    5520     """
# -> 5521     return super()._rename(
#    5522         mapper=mapper,
#    5523         index=index,
#    5524         columns=columns,
#    5525         axis=axis,
#    5526         copy=copy,
#    5527         inplace=inplace,
#    5528         level=level,
#    5529         errors=errors,
#    5530     )
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:1084, in NDFrame._rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1078     if errors == "raise" and len(indexer[indexer == -1]):
#    1079         missing_labels = [
#    1080             label
#    1081             for index, label in enumerate(replacements)
#    1082             if indexer[index] == -1
#    1083         ]
# -> 1084         raise KeyError(f"{missing_labels} not found in axis")
#    1086 new_index = ax._transform_index(f, level=level)
#    1087 result._set_axis_nocheck(new_index, axis=axis_no, inplace=True, copy=False)
#
# KeyError: "['Address'] not found in axis"

# %% [markdown]
# If you set `errors=raise`, you will be alerted if "old names" in your Mapper can't be found.
