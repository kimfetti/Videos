# %% [markdown]
# # Matplotlib: Remove Spines

# %%
from matplotlib import pyplot as plt

# %%
x = range(10)
y = [0, 3, 5, 4, 5, 7, 8, 8, 7, 9]

# %% [markdown]
# ## With matplotlib

# %%
plt.plot(x, y)
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False);

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax.spines
# Out:
# OrderedDict([('left', <matplotlib.spines.Spine at 0x118d84080>),
#              ('right', <matplotlib.spines.Spine at 0x116123dd8>),
#              ('bottom', <matplotlib.spines.Spine at 0x10f3c4198>),
#              ('top', <matplotlib.spines.Spine at 0x1160e0780>)])

# %% [markdown]
# ### Remove all spines with `set_frame_on`

# %%
plt.plot(x, y)
ax = plt.gca()
ax.set_frame_on(False);

# %% [markdown]
# ### Remove for all plots with `rcParams`

# %%
plt.plot(x, y);

# %%
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False

# %%
plt.plot(x, y);

# %%
plt.scatter(x, y);

# %%
plt.rcParams['axes.spines.top'] = True
plt.rcParams['axes.spines.right'] = True

# %% [markdown]
# ## With Seaborn

# %%
import seaborn as sns

# %%
plt.plot(x, y);

# %% [markdown]
# ### Removing other spines
#
# By default, `sns.despine()` removes top and left spines.  Use arguments to update.
#
# Default: `sns.despine(left=False, bottom=False, right=True, top=True)`

# %%
plt.plot(x, y)
sns.despine();

# %%
plt.plot(x, y)
sns.despine(left=True, right=False);

# %% [markdown]
# ## Thumbnail Image and Overlays

# %%
plt.figure(figsize=(6, 4))
plt.plot(x, y, lw=5)
plt.xticks([])
plt.yticks([])
ax = plt.gca()
ax.spines['right'].set_color('gray')
ax.spines['right'].set_linestyle((0,(10,10)))
for spine in ax.spines:
    ax.spines[spine].set_linewidth(2)
ax.spines['right'].set_linewidth(1)
#plt.savefig('11spines_thumb.png', dpi=200, bbox_inches='tight');
